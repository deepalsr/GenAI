# %% [markdown]
# Strings

# %%
a = "Hello World"
print(a[1])
# Out:
# e

# %% [markdown]
# Looping through a string

# %%
for x in "bananas":
    print(x)
# Out:
# b
# a
# n
# a
# n
# a
# s

# %% [markdown]
# String Lenght

# %%
a = "Hello World"
print(len(a))
# Out:
# 11

# %% [markdown]
# Check String

# %%
txt = "I am Deepal"
print("am" in txt)
# Out:
# True

# %% [markdown]
# Slicing Strings

# %%
b = "Hello World"
print(b[2:5])
# Out:
# llo

# %%
b = "Hello World"
print(b[:5])
# Out:
# Hello

# %%
b = "Hello World"
print(b[2:])
# Out:
# llo World

# %%
b = "Hello World"
print(b[-3:-1])
# Out:
# rl

# %% [markdown]
# Modifying strings

# %%
b = "Hello World"
print(b.upper())
# Out:
# HELLO WORLD

# %%
b = "Hello World"
print(b.lower())
# Out:
# hello world

# %%
b = "Hello World"
print(b.replace("H","U"))
# Out:
# Uello World

# %%
b = "Hello World"
print(b.split(" "))
# Out:
# ['Hello', 'World']

# %% [markdown]
# Concatenate String

# %%
a= "Hello"
b= "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
a= "Hello"
b= "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %% [markdown]
# String Format

# %%
age = 22
txt = f"My name is Deepal, I am {age}"
print(txt)
# Out:
# My name is Deepal, I am 22

# %%
price = 60
print(f"The price is {price:.2f} ruppees")
# Out:
# The price is 60.00 ruppees

# %%
price = 60
item = 5
print(f"The price is {price:.2f} ruppees for {item} items")
# Out:
# The price is 60.00 ruppees for 5 items

# %% [markdown]
# Escape character

# %%
txt = "We are the so called \"Vikings\" from the north"
print(txt)
# Out:
# We are the so called "Vikings" from the north
