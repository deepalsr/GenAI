# %% [markdown]
# List

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
print(len(thislist))
# Out:
# 3

# %%
thislist = list(("apple","banana","cherry"))
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[1])
# Out:
# banana

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[-1])
# Out:
# cherry

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
print(thislist[2:5])
# Out:
# ['cherry', 'mango', 'kiwi']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
print(thislist[:5])
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'kiwi']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
print(thislist[2:])
# Out:
# ['cherry', 'mango', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
print(thislist[-4:-1])
# Out:
# ['cherry', 'mango', 'kiwi']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
if "apple" in thislist:
    print("Yes, 'apple' is in the fruits list")
# Out:
# Yes, 'apple' is in the fruits list

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
thislist[1] = "guava"
print(thislist)
# Out:
# ['apple', 'guava', 'cherry', 'mango', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
thislist[2:5]=["guava", "watermelon", "tomato"]
print(thislist)
# Out:
# ['apple', 'banana', 'guava', 'watermelon', 'tomato', 'mango']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
thislist[2:5]=["guava"]
print(thislist)
# Out:
# ['apple', 'banana', 'guava', 'mango']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
thislist.insert(2, "guava")
print(thislist)
# Out:
# ['apple', 'banana', 'guava', 'cherry', 'mango', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'kiwi', 'mango', 'orange']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
thatlist = ["hi","hello","bye"]
thislist.extend(thatlist)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'kiwi', 'mango', 'hi', 'hello', 'bye']

# %%
thislist = ["apple", "banana", "orange"]
thistuple =["kiwi", "orange"]
thislist.extend(thistuple)
print(thislist)
# Out:
# ['apple', 'banana', 'orange', 'kiwi', 'orange']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
thislist.remove("apple")
print(thislist)
# Out:
# ['banana', 'cherry', 'mango', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry', 'mango', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
thislist.pop()
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'kiwi']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
del thislist[1]
print(thislist)
# Out:
# ['apple', 'cherry', 'mango', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
del thislist

# %%
thislist = ["apple", "banana", "cherry", "mango", "kiwi", "mango"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
thislist = [1 , 2, 3, 4, 5]
for x in thislist:
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
thislist = [1 , 2, 3, 4, 5]
for i in range(len(thislist)):
    print(thislist[i])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
thislist = [1 , 2, 3, 4, 5]
i = 0
while i< len(thislist):
    print(thislist[i])
    i= i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
thislist = [1 , 2, 3, 4, 5]
[print(x) for x in thislist]
# Out:
# 1
# 2
# 3
# 4
# 5
# [None, None, None, None, None]

# %%
thislist = ["apple" , "banana", "kiwi", "guava", "tomato"]

newlist = [x for x in thislist if "a" in x]

print(newlist)
# Out:
# ['apple', 'banana', 'guava', 'tomato']

# %%
thislist = ["apple" , "banana", "kiwi", "guava", "tomato"]

newlist = [x for x in thislist if x != "apple"]

print(newlist)
# Out:
# ['banana', 'kiwi', 'guava', 'tomato']

# %%
thislist = ["apple" , "banana", "kiwi", "guava", "tomato"]

newlist = [x for x in thislist]

print(newlist)
# Out:
# ['apple', 'banana', 'kiwi', 'guava', 'tomato']

# %%
thislist = ["apple" , "banana", "kiwi", "guava", "tomato"]

newlist = [x for x in range(len(thislist[0:3]))]

print(newlist)
# Out:
# [0, 1, 2]

# %%
thislist = ["apple" , "banana", "kiwi", "guava", "tomato"]

newlist = [x.upper() for x in thislist]

print(newlist)
# Out:
# ['APPLE', 'BANANA', 'KIWI', 'GUAVA', 'TOMATO']

# %%
thislist = ["apple" , "banana", "kiwi", "guava", "tomato"]

newlist = ["joker" for x in thislist if "a" in x]

print(newlist)
# Out:
# ['joker', 'joker', 'joker', 'joker']

# %%
thislist = ["apple" , "banana", "kiwi", "guava", "tomato"]

newlist = [x if x != "banana" else "orange" for x in thislist]

print(newlist)
# Out:
# ['apple', 'orange', 'kiwi', 'guava', 'tomato']

# %%
thislist = [100, 500, 400, 300, 200]
thislist.sort()
print(thislist)
# Out:
# [100, 200, 300, 400, 500]

# %%
thislist = [100, 500, 400, 300, 200]
thislist.sort(reverse = True)
print(thislist)
# Out:
# [500, 400, 300, 200, 100]

# %%
def myfunc(n):
    return abs(n- 50)

thislist = [100,25,60,70,80]
thislist.sort(key= myfunc)
print(thislist)
# Out:
# [60, 70, 25, 80, 100]

# %%
thislist = ["apple" , "banana", "Kiwi", "guava", "tomato"]

thislist.sort()
print(thislist)
# Out:
# ['Kiwi', 'apple', 'banana', 'guava', 'tomato']

# %%
thislist = ["apple" , "banana", "Kiwi", "guava", "tomato"]
thislist.sort(key = str.lower)
print(thislist)
# Out:
# ['apple', 'banana', 'guava', 'Kiwi', 'tomato']

# %%
thislist = ["apple" , "banana", "Kiwi", "guava", "tomato"]
thislist.reverse()
print(thislist)
# Out:
# ['tomato', 'guava', 'Kiwi', 'banana', 'apple']

# %%
thislist = ["apple" , "banana", "kiwi", "guava", "tomato"]

newlist = thislist.copy()
print(newlist)
# Out:
# ['apple', 'banana', 'kiwi', 'guava', 'tomato']

# %%
thislist = ["apple" , "banana", "kiwi", "guava", "tomato"]

newlist = list(thislist)

print(newlist)
# Out:
# ['apple', 'banana', 'kiwi', 'guava', 'tomato']

# %%
thislist = ["apple" , "banana", "kiwi", "guava", "tomato"]

newlist = thislist[:]

print(newlist)
# Out:
# ['apple', 'banana', 'kiwi', 'guava', 'tomato']

# %%
list1 = ["a", "b", "c"]
list2 = [1,2,3]

list3 = list1 +list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1 = ["a", "b", "c"]
list2 = [1,2,3]

for x in list2:
    list1.append(x)

print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1 = ["a", "b", "c"]
list2 = [1,2,3]

list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]
